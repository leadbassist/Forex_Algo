# %%
import sys
sys.path.append("../")
from plotting import CandlePlot
import pandas as pd

# %%
from technicals.patterns import apply_patterns

# %%
df = pd.read_pickle("../data/GBP_JPY_H1.pkl")

# %%
df_an = df[['time', 'mid_o', 'mid_h', 'mid_l', 'mid_c']].copy()

# %%
df_an.tail()
# Out:
#                            time    mid_o    mid_h    mid_l    mid_c
# 37219 2021-12-30 19:00:00+00:00  155.312  155.444  155.274  155.444
# 37220 2021-12-30 20:00:00+00:00  155.442  155.470  155.289  155.312
# 37221 2021-12-30 21:00:00+00:00  155.317  155.382  155.286  155.382
# 37222 2021-12-30 22:00:00+00:00  155.353  155.381  155.282  155.329
# 37223 2021-12-30 23:00:00+00:00  155.336  155.360  155.284  155.310

# %%
df_an = apply_patterns(df_an)

# %%
df_an.tail()
# Out:
#                            time    mid_o    mid_h    mid_l    mid_c  \
# 37219 2021-12-30 19:00:00+00:00  155.312  155.444  155.274  155.444
# 37220 2021-12-30 20:00:00+00:00  155.442  155.470  155.289  155.312
# 37221 2021-12-30 21:00:00+00:00  155.317  155.382  155.286  155.382
# 37222 2021-12-30 22:00:00+00:00  155.353  155.381  155.282  155.329
# 37223 2021-12-30 23:00:00+00:00  155.336  155.360  155.284  155.310
#
#        body_lower  body_upper  body_bottom_perc  body_top_perc  body_perc  \
# 37219     155.312     155.444         22.352941     100.000000  77.647059
# 37220     155.312     155.442         12.707182      84.530387  71.823204
# 37221     155.317     155.382         32.291667     100.000000  67.708333
# 37222     155.329     155.353         47.474747      71.717172  24.242424
# 37223     155.310     155.336         34.210526      68.421053  34.210526
#
#        ...  direction_prev_2  HANGING_MAN  SHOOTING_STAR  SPINNING_TOP  \
# 37219  ...              -1.0        False          False         False
# 37220  ...              -1.0        False          False         False
# 37221  ...               1.0        False          False         False
# 37222  ...              -1.0        False          False         False
# 37223  ...               1.0        False          False         False
#
#        MARUBOZU  TWEEZER_TOP  TWEEZER_BOTTOM  MORNING_STAR  EVENING_STAR  \
# 37219     False        False           False         False         False
# 37220     False        False           False         False         False
# 37221     False        False           False         False         False
# 37222     False        False           False         False         False
# 37223     False        False           False         False         False
#
#        ENGULFING
# 37219       True
# 37220      False
# 37221      False
# 37222      False
# 37223      False
#
# [5 rows x 31 columns]

# %%
df_an.describe()
# Out:
#               mid_o         mid_h         mid_l         mid_c    body_lower  \
# count  37224.000000  37224.000000  37224.000000  37224.000000  37224.000000
# mean     144.379960    144.514898    144.241770    144.380024    144.314048
# std        8.377065      8.379556      8.373667      8.375775      8.373819
# min      125.038000    125.431000    124.044000    125.042000    125.038000
# 25%      138.583000    138.723750    138.437500    138.581750    138.515750
# 50%      144.083000    144.206000    143.952000    144.085500    144.032500
# 75%      150.299250    150.418250    150.164000    150.298500    150.232500
# max      174.957000    175.018000    174.669000    174.957000    174.760000
#
#          body_upper  body_bottom_perc  body_top_perc     body_perc  \
# count  37224.000000      37217.000000   37217.000000  37217.000000
# mean     144.445936         28.639096      72.601234     43.962138
# std        8.378502         20.808306      20.471193     25.502357
# min      125.158000          0.000000       1.886792      0.000000
# 25%      138.644000         11.587983      59.302326     22.591362
# 50%      144.145000         25.000000      76.351351     43.500000
# 75%      150.367250         42.424242      89.371981     64.541833
# max      174.957000        100.000000     100.000000    100.000000
#
#           direction  ...    low_change   high_change  body_size_change  \
# count  37224.000000  ...  37223.000000  37223.000000      3.721900e+04
# mean       0.022620  ...     -0.000183     -0.000204               inf
# std        0.999758  ...      0.150523      0.137937               NaN
# min       -1.000000  ...     -7.007838     -8.082472     -1.000000e+02
# 25%       -1.000000  ...     -0.046579     -0.049970     -6.044366e+01
# 50%        1.000000  ...      0.005491     -0.003520     -4.629630e-01
# 75%        1.000000  ...      0.053023      0.046707      1.506259e+02
# max        1.000000  ...      2.878679      2.676402               inf
#
#           mid_point  mid_point_prev_2  body_size_prev  body_perc_prev  \
# count  37224.000000      37222.000000    37223.000000    37216.000000
# mean     144.378334        144.377746        0.131890       43.962400
# std        8.375746          8.375587        0.172446       25.502649
# min      124.833000        124.833000        0.000000        0.000000
# 25%      138.570875        138.570625        0.038000       22.591362
# 50%      144.085000        144.085000        0.085000       43.500000
# 75%      150.309625        150.308375        0.170000       64.541922
# max      174.813000        174.813000       12.839000      100.000000
#
#        body_perc_prev_2  direction_prev  direction_prev_2
# count      37215.000000    37223.000000      37222.000000
# mean          43.962930        0.022647          0.022675
# std           25.502787        0.999757          0.999756
# min            0.000000       -1.000000         -1.000000
# 25%           22.591362       -1.000000         -1.000000
# 50%           43.500000        1.000000          1.000000
# 75%           64.542011        1.000000          1.000000
# max          100.000000        1.000000          1.000000
#
# [8 rows x 21 columns]

# %%
import plotly.graph_objects as go

# %%
# plot
MARKER = '#0066FF'
dfp = df_an.iloc[-200:]
cp = CandlePlot(dfp, candles=True)
df_temp = cp.df_plot[cp.df_plot.ENGULFING==True]
cp.fig.add_trace(
                go.Candlestick(
                    x=df_temp.sTime,
                    open=df_temp.mid_o,
                    high=df_temp.mid_h,
                    low=df_temp.mid_l,
                    close=df_temp.mid_c,
                    line=dict(width=1),
                    opacity=1,
                    increasing_fillcolor=MARKER,
                    decreasing_fillcolor=MARKER,
                    increasing_line_color=MARKER,
                    decreasing_line_color=MARKER,
                )
            )
cp.show_plot()
# Out:
# <div>                            <div id="7279bfe6-9e20-4fd2-b71f-fcc4822dd147" class="plotly-graph-div" style="height:400px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7279bfe6-9e20-4fd2-b71f-fcc4822dd147")) {                    Plotly.newPlot(                        "7279bfe6-9e20-4fd2-b71f-fcc4822dd147",                        [{"close":[150.006,149.969,150.13,150.12,150.137,150.102,150.08,150.147,150.016,150.177,150.158,150.176,150.174,150.324,150.35,150.274,150.422,150.544,150.628,150.584,150.716,150.786,150.812,150.966,151.2,151.315,151.342,151.36,151.385,151.402,151.365,151.252,151.353,151.445,151.28,151.272,151.274,151.206,151.284,151.52,151.669,151.847,152.166,152.074,151.988,152.194,152.228,152.543,152.426,152.55,152.486,152.524,152.448,152.424,152.35,152.37,152.51,152.362,152.387,152.346,152.375,152.444,152.508,152.755,152.974,153.